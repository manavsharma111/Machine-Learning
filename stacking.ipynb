# %% [markdown]
# <a href="https://colab.research.google.com/github/manavsharma111/Machine-Learning/blob/main/stacking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
# import sheryanalysis as sys
warnings.filterwarnings('ignore')

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import StackingClassifier
# import sklearn.svm
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
df = pd.read_csv('Iris.csv')

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
X=df.drop(['Species', 'Id'], axis=1)
y=df['Species']

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,y,test_size=0.5,random_state=1)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
base_learnes = [
    ('knn', KNeighborsClassifier(n_neighbors=50, weights='uniform', metric='manhattan')),
    ('lr', LogisticRegression(max_iter=2)),
    ('svm', SVC(probability=True, kernel='linear', C=0.1)),
    ('dt', DecisionTreeClassifier(max_depth=2))
]

# %%
meta_learner = LogisticRegression(max_iter=2)

# %%
stacking_clf = StackingClassifier(
    estimators=base_learnes,
    final_estimator=meta_learner,
    cv=5
    )

# %%
stacking_clf.fit(X_train, Y_train)
# Out:
# StackingClassifier(cv=5,
#                    estimators=[('knn',
#                                 KNeighborsClassifier(metric='manhattan',
#                                                      n_neighbors=50)),
#                                ('lr', LogisticRegression(max_iter=10)),
#                                ('svm',
#                                 SVC(C=0.1, kernel='linear', probability=True)),
#                                ('dt', DecisionTreeClassifier(max_depth=2))],
#                    final_estimator=LogisticRegression(max_iter=10))

# %%
Y_pred = stacking_clf.predict(X_test)

# %%
accuracy = accuracy_score(Y_test, Y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9333333333333333
